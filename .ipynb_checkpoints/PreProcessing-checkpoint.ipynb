# %% [markdown]
# # Outlier Exclusion

# %%
import mltools as ml
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import ShuffleSplit
from sklearn import neighbors

Xtr = np.genfromtxt("data/X_train.txt",delimiter=None)
Ytr = np.genfromtxt("data/Y_train.txt",delimiter=None)
Xte = np.genfromtxt("data/X_test.txt",delimiter=None)

# Xtr,param = ml.transforms.rescale(Xtr)
# Xte,_ = ml.transforms.rescale(Xte)

#%%
out4 = np.all([Xtr[:,4]>12000,Ytr>30],axis=0)
out5 = np.all([Xtr[:,5]>6000, Ytr>30],axis=0)
out7 = np.any([np.all([Xtr[:,7]>15, Ytr>20],axis=0),\
               np.all([Xtr[:,7]>25, Ytr>10],axis=0)],\
              axis=0)
out8 = np.any([np.all([Xtr[:,8]>17,   Ytr>10],axis=0),\
               np.all([Xtr[:,8]>17.5, Ytr>10],axis=0)],axis=0)
out9 =  np.all([Xtr[:,9]>11,   Ytr>10],axis=0)
out10 = np.all([Xtr[:,10]>13,  Ytr>20,  Ytr<40],axis=0)
out12 = np.all([Xtr[:,12]>40,  Ytr>10],axis=0)
out13 = np.all([Xtr[:,13]>400, Ytr>10],axis=0)

outX0 = np.any([Xtr[:,9]==0, Xtr[:,10]==0, Xtr[:,11]==0], axis=0)

outMask = np.any([Xtr[:,7]>40, Xtr[:,12]>400, Xtr[:,11]>40],axis=0)

outMask = np.any([outMask, out4, out5, out7, out8, out10, out12, out13], axis=0)
print(np.sum(outMask))
X,Y = Xtr[~outMask],Ytr[~outMask]

# Cross Validation
rs0 = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
Xsp0 = rs0.split(X)

# rescalse
X,param = ml.transforms.rescale(X)
Xte,_ = ml.transforms.rescale(Xte)

XtCV = []
XvCV = []
YtCV = []
YvCV = []
for tr_idx, va_idx in Xsp0:
    XtCV.append(X[tr_idx])
    XvCV.append(X[va_idx])
    YtCV.append(Y[tr_idx])
    YvCV.append(Y[va_idx])
# Out:
# 88

# %%
plt.hist(Ytr,bins=list(range(0,75,2)))
plt.title("Histogram of Ytr")
plt.xlabel("ranfall")
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
# Data Visualization
for i in range(14):
    plt.figure()
    plt.clf()
    plt.title("feature %d"%i)
    for y in range(0,80,10):
        mask1 = Ytr>=y
        mask2 = Ytr<(y+10)
        mask = np.all([mask1,mask2], axis=0)
        plt.plot(Xtr[mask][:,i],Ytr[mask],".")
    plt.show()

# %% [markdown]
# ## Data Visualization after Excluding Outliers

# %%
# Data Visualization
for i in range(14):
    plt.figure()
    plt.clf()
    plt.title("feature %d"%i)
    for y in range(0,80,10):
        mask1 = Y>=y
        mask2 = Y<(y+10)
        mask = np.all([mask1,mask2], axis=0)
        plt.plot(X[mask][:,i],Y[mask],".")
    plt.show()

# %% [markdown]
# ## Effectiveness

# %% [markdown]
# After excluding outliers manually, the mse for our KNN regressor dropped by more than 0.1

# %% [markdown]
# ## PCA

# %%
for i in range(13):
    for j in range(i+1,14):
        plt.figure()
        plt.title("x%d vs x%d"%(i,j))
        for y in range(0,80,10):
            mask1 = Ytr>=y
            mask2 = Ytr<(y+10)
            mask = np.all([mask1,mask2], axis=0)
            plt.plot(Xtr[mask][:,i],Xtr[mask][:,j],".")
        plt.show()

# %% [markdown]
# Feature 3 and Feature 12 are pretty bad at distinguishing data with different Y values.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=12,svd_solver='full')

# %%
Y = Ytr[:20000]
Yv = Ytr[20000:40000]
K = [2*k for k in range(2,10)]
for n in range(1,14):
    pca = PCA(n_components=n)
    Xi = pca.fit_transform(Xtr)
    X = Xi[:20000]
    Xv = Xi[20000:40000]
    errTri = []
    errVai = []
    for i in K:
        knni = neighbors.KNeighborsRegressor(i)
        knni.fit(X,Y)
        errTri.append(mse(knni.predict(X),Y))
        errVai.append(mse(knni.predict(Xv),Yv))
    plt.figure(1)
    plt.semilogx(K,errTri,'*-',label="%d components"%n)
    plt.figure(2)
    plt.semilogx(K,errVai,'*-',label="%d components"%n)

plt.figure(1)
plt.legend()
plt.title("KNN Train Err vs PCA")
plt.xlabel("k")
plt.show()
plt.figure(2)
plt.legend()
plt.title("KNN Valid Err vs PCA")
plt.xlabel("k")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Xnew = pca.fit_transform(X)
XteNew = pca.transform(Xte)

# %%
print("PCA variance\n",pca.explained_variance_)
print("PCA componentes ratio\n",pca.explained_variance_ratio_)
# Out:
# PCA variance
#  [1.76277658e+07 1.24781250e+06 1.91975877e+05 3.45133528e+03
#  2.23380085e+02 8.83321553e+01 4.22992831e+01 7.98082834e+00
#  6.02749858e+00 4.20614709e+00 2.48142634e+00 5.09763071e-01]
# PCA componentes ratio
#  [9.24304619e-01 6.54285330e-02 1.00661758e-02 1.80969339e-04
#  1.17128425e-05 4.63166007e-06 2.21794544e-06 4.18471437e-07
#  3.16049398e-07 2.20547585e-07 1.30112565e-07 2.67292160e-08]

# %%
Xnew,param = ml.transforms.rescale(Xnew)
XteNew,_ = ml.transforms.rescale(XteNew,param)

# %%
knnL = neighbors.KNeighborsRegressor(16)
knnL.fit(Xnew,Y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=16, p=2,
#           weights='uniform')

# %%
YteHat = knnL.predict(XteNew)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-146f9a4eeea5> in <module>()
#       1 YteHat = knnL.predict(XteNew)
# ----> 2 Yte[Yte<0]=0
#
# NameError: name 'Yte' is not defined

# %%
YteHat[YteHat<0]=0

# %%
fh = open("knn_w_pre.csv","w")
fh.write("ID,Prediction\n")
for i,yi in enumerate(YteHat):
    fh.write('{},{}\n'.format(i,yi))
fh.close()
